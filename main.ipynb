# %% [markdown]
# # 제목 1

# %% [markdown]
# *   목록 1
# *   목록 2

# %%
print('안녕, 파이썬!')
# Out:
# 안녕, 파이썬!

# %%
def say_hi(name):
    print(f'안녕, {name}!')

# %%
say_hi('오쌤')
# Out:
# 안녕, 오쌤!

# %%
import random

# %%
random.random()
# Out:
# 0.26914951150331656

# %%
random.randrange(100)
# Out:
# 47
